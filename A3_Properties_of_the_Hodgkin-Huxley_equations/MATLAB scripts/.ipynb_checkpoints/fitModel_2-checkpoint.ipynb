# %% [markdown]
# This code is to fit a model to the second threshold as a function of time between interstimulus currents

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([5,10,20,30,50,70,100])
y = np.array([12.5,75,87.5,100,125,137.5,150])
t = np.linspace(0,105,500)

# %%
plt.plot(x,y,'o')
plt.xlim(0,105)
plt.xlabel("Time")
plt.ylabel("Threshold to the second pulse ")
plt.show()

# %%
best_error = 100000
best_A = 0
best_Alpha = 0
best_b = 0

for b in range(0,12):
    for k in range(0,15000):
        a=k/10
        for alpha in range(1,100):
            al = alpha / 100
            temp = b+a*np.exp(-al*x)
            error = np.sqrt(sum((temp-y)**2))
            if error<best_error:
                best_error = error
                best_A = a
                best_Alpha = al
                best_b = b

print("Done")
# Out:
# Done

# %%
best_error
# Out:
# 3.4395261748747408

# %%
best_A
# Out:
# 1387.6

# %%
best_Alpha
# Out:
# 0.39

# %%
best_b
# Out:
# 11

# %% [markdown]
# Therefore the solution model is, $threshold(t) = 1387.6 e^{-0.39t} + 11$

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(t,best_b+best_A*np.exp(-best_Alpha*t))
ax.plot(x,y,'o')
ax.set_xlabel('time')
ax.set_ylabel('current amplitude')
ax.set_title("$Model --> threshold(t) = 1387.6 e^{-0.39t} + 11$")
plt.show()
